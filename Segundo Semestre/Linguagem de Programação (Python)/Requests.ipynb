# %%
import requests

info = requests.get('https://api.github.com/events')
info.headers
# Out:
# {'Server': 'GitHub.com', 'Date': 'Wed, 13 Mar 2024 17:10:47 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Cache-Control': 'public, max-age=60, s-maxage=60', 'Vary': 'Accept, Accept-Encoding, Accept, X-Requested-With', 'ETag': 'W/"fe1fed2002b783d9d1144023c72c9a71e7a36cac49e6cc1fca6903c9bf7b16c9"', 'Last-Modified': 'Wed, 13 Mar 2024 17:05:46 GMT', 'X-Poll-Interval': '60', 'X-GitHub-Media-Type': 'github.v3; format=json', 'Link': '<https://api.github.com/events?page=2>; rel="next", <https://api.github.com/events?page=10>; rel="last"', 'x-github-api-version-selected': '2022-11-28', 'Access-Control-Expose-Headers': 'ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Used, X-RateLimit-Resource, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media-Type, X-GitHub-SSO, X-GitHub-Request-Id, Deprecation, Sunset', 'Access-Control-Allow-Origin': '*', 'Strict-Transport-Security': 'max-age=31536000; includeSubdomains; preload', 'X-Frame-Options': 'deny', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '0', 'Referrer-Policy': 'origin-when-cross-origin, strict-origin-when-cross-origin', 'Content-Security-Policy': "default-src 'none'", 'Content-Encoding': 'gzip', 'X-RateLimit-Limit': '60', 'X-RateLimit-Remaining': '58', 'X-RateLimit-Reset': '1710353415', 'X-RateLimit-Resource': 'core', 'X-RateLimit-Used': '2', 'Accept-Ranges': 'bytes', 'Transfer-Encoding': 'chunked', 'X-GitHub-Request-Id': '995E:3D2673:1930B07:1A1B102:65F1DE16'}

# %%
print(info.headers['date']) # Data de extração
print(info.headers['server']) # Servidor de origem
#print(info.headers['status']) # Status HTTP da extração, 200 é ok
print(info.encoding) # Encoding do texto
print(info.headers['last-modified']) # Data da última modificação da informação
# Out:
# Wed, 13 Mar 2024 17:10:47 GMT
# GitHub.com
# utf-8
# Wed, 13 Mar 2024 17:05:46 GMT

# %%
texto_str = info.text
print(type(texto_str))
texto_str[:100] # exibe somente os 100 primeiros caracteres
# Out:
# <class 'str'>
# '[{"id":"36520208274","type":"PullRequestEvent","actor":{"id":49478222,"login":"odzhychko","display_l'

# %%
texto_json = info.json()
print(type(texto_json))
texto_json[0]
# Out:
# <class 'list'>
# {'id': '36520208274',
#  'type': 'PullRequestEvent',
#  'actor': {'id': 49478222,
#   'login': 'odzhychko',
#   'display_login': 'odzhychko',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/odzhychko',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/49478222?'},
#  'repo': {'id': 533211353,
#   'name': 'modelix/modelix.core',
#   'url': 'https://api.github.com/repos/modelix/modelix.core'},
#  'payload': {'action': 'closed',
#   'number': 599,
#   'pull_request': {'url': 'https://api.github.com/repos/modelix/modelix.core/pulls/599',
#    'id': 1769806386,
#    'node_id': 'PR_kwDOH8go2c5pfRoy',
#    'html_url': 'https://github.com/modelix/modelix.core/pull/599',
#    'diff_url': 'https://github.com/modelix/modelix.core/pull/599.diff',
#    'patch_url': 'https://github.com/modelix/modelix.core/pull/599.patch',
#    'issue_url': 'https://api.github.com/repos/modelix/modelix.core/issues/599',
#    'number': 599,
#    'state': 'closed',
#    'locked': False,
#    'title': 'build(deps): bump modelixBuildtools from 1.3.0 to 1.4.0',
#    'user': {'login': 'dependabot[bot]',
#     'id': 49699333,
#     'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/in/29110?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#     'html_url': 'https://github.com/apps/dependabot',
#     'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#     'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#     'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#     'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#     'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#     'type': 'Bot',
#     'site_admin': False},
#    'body': "Bumps `modelixBuildtools` from 1.3.0 to 1.4.0.\nUpdates `org.modelix.mps:build-tools-gradle` from 1.3.0 to 1.4.0\n\nUpdates `org.modelix.mps:build-tools-lib` from 1.3.0 to 1.4.0\n\nUpdates `org.modelix.mps.build-tools` from 1.3.0 to 1.4.0\n\n\nDependabot will resolve any conflicts with this PR as long as you don't alter it yourself. You can also trigger a rebase manually by commenting `@dependabot rebase`.\n\n[//]: # (dependabot-automerge-start)\n[//]: # (dependabot-automerge-end)\n\n---\n\n<details>\n<summary>Dependabot commands and options</summary>\n<br />\n\nYou can trigger Dependabot actions by commenting on this PR:\n- `@dependabot rebase` will rebase this PR\n- `@dependabot recreate` will recreate this PR, overwriting any edits that have been made to it\n- `@dependabot merge` will merge this PR after your CI passes on it\n- `@dependabot squash and merge` will squash and merge this PR after your CI passes on it\n- `@dependabot cancel merge` will cancel a previously requested merge and block automerging\n- `@dependabot reopen` will reopen this PR if it is closed\n- `@dependabot close` will close this PR and stop Dependabot recreating it. You can achieve the same result by closing it manually\n- `@dependabot show <dependency name> ignore conditions` will show all of the ignore conditions of the specified dependency\n- `@dependabot ignore this major version` will close this PR and stop Dependabot creating any more for this major version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this minor version` will close this PR and stop Dependabot creating any more for this minor version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this dependency` will close this PR and stop Dependabot creating any more for this dependency (unless you reopen the PR or upgrade to it yourself)\n\n\n</details>",
#    'created_at': '2024-03-13T10:50:16Z',
#    'updated_at': '2024-03-13T17:05:46Z',
#    'closed_at': '2024-03-13T17:05:45Z',
#    'merged_at': '2024-03-13T17:05:45Z',
#    'merge_commit_sha': '7d86075fe35c482a42944888ebb1fdbc8e12384b',
#    'assignee': None,
#    'assignees': [],
#    'requested_reviewers': [],
#    'requested_teams': [],
#    'labels': [{'id': 5439878716,
#      'node_id': 'LA_kwDOH8go2c8AAAABRD32PA',
#      'url': 'https://api.github.com/repos/modelix/modelix.core/labels/dependencies',
#      'name': 'dependencies',
#      'color': '0366d6',
#      'default': False,
#      'description': 'Pull requests that update a dependency file'},
#     {'id': 5456170296,
#      'node_id': 'LA_kwDOH8go2c8AAAABRTaNOA',
#      'url': 'https://api.github.com/repos/modelix/modelix.core/labels/java',
#      'name': 'java',
#      'color': 'ffa221',
#      'default': False,
#      'description': 'Pull requests that update Java code'}],
#    'milestone': None,
#    'draft': False,
#    'commits_url': 'https://api.github.com/repos/modelix/modelix.core/pulls/599/commits',
#    'review_comments_url': 'https://api.github.com/repos/modelix/modelix.core/pulls/599/comments',
#    'review_comment_url': 'https://api.github.com/repos/modelix/modelix.core/pulls/comments{/number}',
#    'comments_url': 'https://api.github.com/repos/modelix/modelix.core/issues/599/comments',
#    'statuses_url': 'https://api.github.com/repos/modelix/modelix.core/statuses/b9e5c5c8b4b5c63052200dd1ea813ee001ab64c9',
#    'head': {'label': 'modelix:dependabot/gradle/modelixBuildtools-1.4.0',
#     'ref': 'dependabot/gradle/modelixBuildtools-1.4.0',
#     'sha': 'b9e5c5c8b4b5c63052200dd1ea813ee001ab64c9',
#     'user': {'login': 'modelix',
#      'id': 66949436,
#      'node_id': 'MDEyOk9yZ2FuaXphdGlvbjY2OTQ5NDM2',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/66949436?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/modelix',
#      'html_url': 'https://github.com/modelix',
#      'followers_url': 'https://api.github.com/users/modelix/followers',
#      'following_url': 'https://api.github.com/users/modelix/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/modelix/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/modelix/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/modelix/subscriptions',
#      'organizations_url': 'https://api.github.com/users/modelix/orgs',
#      'repos_url': 'https://api.github.com/users/modelix/repos',
#      'events_url': 'https://api.github.com/users/modelix/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/modelix/received_events',
#      'type': 'Organization',
#      'site_admin': False},
#     'repo': {'id': 533211353,
#      'node_id': 'R_kgDOH8go2Q',
#      'name': 'modelix.core',
#      'full_name': 'modelix/modelix.core',
#      'private': False,
#      'owner': {'login': 'modelix',
#       'id': 66949436,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjY2OTQ5NDM2',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/66949436?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/modelix',
#       'html_url': 'https://github.com/modelix',
#       'followers_url': 'https://api.github.com/users/modelix/followers',
#       'following_url': 'https://api.github.com/users/modelix/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/modelix/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/modelix/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/modelix/subscriptions',
#       'organizations_url': 'https://api.github.com/users/modelix/orgs',
#       'repos_url': 'https://api.github.com/users/modelix/repos',
#       'events_url': 'https://api.github.com/users/modelix/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/modelix/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'html_url': 'https://github.com/modelix/modelix.core',
#      'description': 'Mostly model related components',
#      'fork': False,
#      'url': 'https://api.github.com/repos/modelix/modelix.core',
#      'forks_url': 'https://api.github.com/repos/modelix/modelix.core/forks',
#      'keys_url': 'https://api.github.com/repos/modelix/modelix.core/keys{/key_id}',
#      'collaborators_url': 'https://api.github.com/repos/modelix/modelix.core/collaborators{/collaborator}',
#      'teams_url': 'https://api.github.com/repos/modelix/modelix.core/teams',
#      'hooks_url': 'https://api.github.com/repos/modelix/modelix.core/hooks',
#      'issue_events_url': 'https://api.github.com/repos/modelix/modelix.core/issues/events{/number}',
#      'events_url': 'https://api.github.com/repos/modelix/modelix.core/events',
#      'assignees_url': 'https://api.github.com/repos/modelix/modelix.core/assignees{/user}',
#      'branches_url': 'https://api.github.com/repos/modelix/modelix.core/branches{/branch}',
#      'tags_url': 'https://api.github.com/repos/modelix/modelix.core/tags',
#      'blobs_url': 'https://api.github.com/repos/modelix/modelix.core/git/blobs{/sha}',
#      'git_tags_url': 'https://api.github.com/repos/modelix/modelix.core/git/tags{/sha}',
#      'git_refs_url': 'https://api.github.com/repos/modelix/modelix.core/git/refs{/sha}',
#      'trees_url': 'https://api.github.com/repos/modelix/modelix.core/git/trees{/sha}',
#      'statuses_url': 'https://api.github.com/repos/modelix/modelix.core/statuses/{sha}',
#      'languages_url': 'https://api.github.com/repos/modelix/modelix.core/languages',
#      'stargazers_url': 'https://api.github.com/repos/modelix/modelix.core/stargazers',
#      'contributors_url': 'https://api.github.com/repos/modelix/modelix.core/contributors',
#      'subscribers_url': 'https://api.github.com/repos/modelix/modelix.core/subscribers',
#      'subscription_url': 'https://api.github.com/repos/modelix/modelix.core/subscription',
#      'commits_url': 'https://api.github.com/repos/modelix/modelix.core/commits{/sha}',
#      'git_commits_url': 'https://api.github.com/repos/modelix/modelix.core/git/commits{/sha}',
#      'comments_url': 'https://api.github.com/repos/modelix/modelix.core/comments{/number}',
#      'issue_comment_url': 'https://api.github.com/repos/modelix/modelix.core/issues/comments{/number}',
#      'contents_url': 'https://api.github.com/repos/modelix/modelix.core/contents/{+path}',
#      'compare_url': 'https://api.github.com/repos/modelix/modelix.core/compare/{base}...{head}',
#      'merges_url': 'https://api.github.com/repos/modelix/modelix.core/merges',
#      'archive_url': 'https://api.github.com/repos/modelix/modelix.core/{archive_format}{/ref}',
#      'downloads_url': 'https://api.github.com/repos/modelix/modelix.core/downloads',
#      'issues_url': 'https://api.github.com/repos/modelix/modelix.core/issues{/number}',
#      'pulls_url': 'https://api.github.com/repos/modelix/modelix.core/pulls{/number}',
#      'milestones_url': 'https://api.github.com/repos/modelix/modelix.core/milestones{/number}',
#      'notifications_url': 'https://api.github.com/repos/modelix/modelix.core/notifications{?since,all,participating}',
#      'labels_url': 'https://api.github.com/repos/modelix/modelix.core/labels{/name}',
#      'releases_url': 'https://api.github.com/repos/modelix/modelix.core/releases{/id}',
#      'deployments_url': 'https://api.github.com/repos/modelix/modelix.core/deployments',
#      'created_at': '2022-09-06T07:31:42Z',
#      'updated_at': '2024-03-08T06:09:07Z',
#      'pushed_at': '2024-03-13T17:05:46Z',
#      'git_url': 'git://github.com/modelix/modelix.core.git',
#      'ssh_url': 'git@github.com:modelix/modelix.core.git',
#      'clone_url': 'https://github.com/modelix/modelix.core.git',
#      'svn_url': 'https://github.com/modelix/modelix.core',
#      'homepage': '',
#      'size': 84668,
#      'stargazers_count': 5,
#      'watchers_count': 5,
#      'language': 'Kotlin',
#      'has_issues': True,
#      'has_projects': True,
#      'has_downloads': True,
#      'has_wiki': False,
#      'has_pages': True,
#      'has_discussions': False,
#      'forks_count': 8,
#      'mirror_url': None,
#      'archived': False,
#      'disabled': False,
#      'open_issues_count': 46,
#      'license': {'key': 'apache-2.0',
#       'name': 'Apache License 2.0',
#       'spdx_id': 'Apache-2.0',
#       'url': 'https://api.github.com/licenses/apache-2.0',
#       'node_id': 'MDc6TGljZW5zZTI='},
#      'allow_forking': True,
#      'is_template': False,
#      'web_commit_signoff_required': False,
#      'topics': [],
#      'visibility': 'public',
#      'forks': 8,
#      'open_issues': 46,
#      'watchers': 5,
#      'default_branch': 'main'}},
#    'base': {'label': 'modelix:main',
#     'ref': 'main',
#     'sha': '0678bb881fad1705ae7c511ae6325babf83da2f0',
#     'user': {'login': 'modelix',
#      'id': 66949436,
#      'node_id': 'MDEyOk9yZ2FuaXphdGlvbjY2OTQ5NDM2',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/66949436?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/modelix',
#      'html_url': 'https://github.com/modelix',
#      'followers_url': 'https://api.github.com/users/modelix/followers',
#      'following_url': 'https://api.github.com/users/modelix/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/modelix/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/modelix/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/modelix/subscriptions',
#      'organizations_url': 'https://api.github.com/users/modelix/orgs',
#      'repos_url': 'https://api.github.com/users/modelix/repos',
#      'events_url': 'https://api.github.com/users/modelix/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/modelix/received_events',
#      'type': 'Organization',
#      'site_admin': False},
#     'repo': {'id': 533211353,
#      'node_id': 'R_kgDOH8go2Q',
#      'name': 'modelix.core',
#      'full_name': 'modelix/modelix.core',
#      'private': False,
#      'owner': {'login': 'modelix',
#       'id': 66949436,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjY2OTQ5NDM2',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/66949436?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/modelix',
#       'html_url': 'https://github.com/modelix',
#       'followers_url': 'https://api.github.com/users/modelix/followers',
#       'following_url': 'https://api.github.com/users/modelix/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/modelix/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/modelix/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/modelix/subscriptions',
#       'organizations_url': 'https://api.github.com/users/modelix/orgs',
#       'repos_url': 'https://api.github.com/users/modelix/repos',
#       'events_url': 'https://api.github.com/users/modelix/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/modelix/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'html_url': 'https://github.com/modelix/modelix.core',
#      'description': 'Mostly model related components',
#      'fork': False,
#      'url': 'https://api.github.com/repos/modelix/modelix.core',
#      'forks_url': 'https://api.github.com/repos/modelix/modelix.core/forks',
#      'keys_url': 'https://api.github.com/repos/modelix/modelix.core/keys{/key_id}',
#      'collaborators_url': 'https://api.github.com/repos/modelix/modelix.core/collaborators{/collaborator}',
#      'teams_url': 'https://api.github.com/repos/modelix/modelix.core/teams',
#      'hooks_url': 'https://api.github.com/repos/modelix/modelix.core/hooks',
#      'issue_events_url': 'https://api.github.com/repos/modelix/modelix.core/issues/events{/number}',
#      'events_url': 'https://api.github.com/repos/modelix/modelix.core/events',
#      'assignees_url': 'https://api.github.com/repos/modelix/modelix.core/assignees{/user}',
#      'branches_url': 'https://api.github.com/repos/modelix/modelix.core/branches{/branch}',
#      'tags_url': 'https://api.github.com/repos/modelix/modelix.core/tags',
#      'blobs_url': 'https://api.github.com/repos/modelix/modelix.core/git/blobs{/sha}',
#      'git_tags_url': 'https://api.github.com/repos/modelix/modelix.core/git/tags{/sha}',
#      'git_refs_url': 'https://api.github.com/repos/modelix/modelix.core/git/refs{/sha}',
#      'trees_url': 'https://api.github.com/repos/modelix/modelix.core/git/trees{/sha}',
#      'statuses_url': 'https://api.github.com/repos/modelix/modelix.core/statuses/{sha}',
#      'languages_url': 'https://api.github.com/repos/modelix/modelix.core/languages',
#      'stargazers_url': 'https://api.github.com/repos/modelix/modelix.core/stargazers',
#      'contributors_url': 'https://api.github.com/repos/modelix/modelix.core/contributors',
#      'subscribers_url': 'https://api.github.com/repos/modelix/modelix.core/subscribers',
#      'subscription_url': 'https://api.github.com/repos/modelix/modelix.core/subscription',
#      'commits_url': 'https://api.github.com/repos/modelix/modelix.core/commits{/sha}',
#      'git_commits_url': 'https://api.github.com/repos/modelix/modelix.core/git/commits{/sha}',
#      'comments_url': 'https://api.github.com/repos/modelix/modelix.core/comments{/number}',
#      'issue_comment_url': 'https://api.github.com/repos/modelix/modelix.core/issues/comments{/number}',
#      'contents_url': 'https://api.github.com/repos/modelix/modelix.core/contents/{+path}',
#      'compare_url': 'https://api.github.com/repos/modelix/modelix.core/compare/{base}...{head}',
#      'merges_url': 'https://api.github.com/repos/modelix/modelix.core/merges',
#      'archive_url': 'https://api.github.com/repos/modelix/modelix.core/{archive_format}{/ref}',
#      'downloads_url': 'https://api.github.com/repos/modelix/modelix.core/downloads',
#      'issues_url': 'https://api.github.com/repos/modelix/modelix.core/issues{/number}',
#      'pulls_url': 'https://api.github.com/repos/modelix/modelix.core/pulls{/number}',
#      'milestones_url': 'https://api.github.com/repos/modelix/modelix.core/milestones{/number}',
#      'notifications_url': 'https://api.github.com/repos/modelix/modelix.core/notifications{?since,all,participating}',
#      'labels_url': 'https://api.github.com/repos/modelix/modelix.core/labels{/name}',
#      'releases_url': 'https://api.github.com/repos/modelix/modelix.core/releases{/id}',
#      'deployments_url': 'https://api.github.com/repos/modelix/modelix.core/deployments',
#      'created_at': '2022-09-06T07:31:42Z',
#      'updated_at': '2024-03-08T06:09:07Z',
#      'pushed_at': '2024-03-13T17:05:46Z',
#      'git_url': 'git://github.com/modelix/modelix.core.git',
#      'ssh_url': 'git@github.com:modelix/modelix.core.git',
#      'clone_url': 'https://github.com/modelix/modelix.core.git',
#      'svn_url': 'https://github.com/modelix/modelix.core',
#      'homepage': '',
#      'size': 84668,
#      'stargazers_count': 5,
#      'watchers_count': 5,
#      'language': 'Kotlin',
#      'has_issues': True,
#      'has_projects': True,
#      'has_downloads': True,
#      'has_wiki': False,
#      'has_pages': True,
#      'has_discussions': False,
#      'forks_count': 8,
#      'mirror_url': None,
#      'archived': False,
#      'disabled': False,
#      'open_issues_count': 46,
#      'license': {'key': 'apache-2.0',
#       'name': 'Apache License 2.0',
#       'spdx_id': 'Apache-2.0',
#       'url': 'https://api.github.com/licenses/apache-2.0',
#       'node_id': 'MDc6TGljZW5zZTI='},
#      'allow_forking': True,
#      'is_template': False,
#      'web_commit_signoff_required': False,
#      'topics': [],
#      'visibility': 'public',
#      'forks': 8,
#      'open_issues': 46,
#      'watchers': 5,
#      'default_branch': 'main'}},
#    '_links': {'self': {'href': 'https://api.github.com/repos/modelix/modelix.core/pulls/599'},
#     'html': {'href': 'https://github.com/modelix/modelix.core/pull/599'},
#     'issue': {'href': 'https://api.github.com/repos/modelix/modelix.core/issues/599'},
#     'comments': {'href': 'https://api.github.com/repos/modelix/modelix.core/issues/599/comments'},
#     'review_comments': {'href': 'https://api.github.com/repos/modelix/modelix.core/pulls/599/comments'},
#     'review_comment': {'href': 'https://api.github.com/repos/modelix/modelix.core/pulls/comments{/number}'},
#     'commits': {'href': 'https://api.github.com/repos/modelix/modelix.core/pulls/599/commits'},
#     'statuses': {'href': 'https://api.github.com/repos/modelix/modelix.core/statuses/b9e5c5c8b4b5c63052200dd1ea813ee001ab64c9'}},
#    'author_association': 'CONTRIBUTOR',
#    'auto_merge': None,
#    'active_lock_reason': None,
#    'merged': True,
#    'mergeable': None,
#    'rebaseable': None,
#    'mergeable_state': 'unknown',
#    'merged_by': {'login': 'odzhychko',
#     'id': 49478222,
#     'node_id': 'MDQ6VXNlcjQ5NDc4MjIy',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/49478222?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/odzhychko',
#     'html_url': 'https://github.com/odzhychko',
#     'followers_url': 'https://api.github.com/users/odzhychko/followers',
#     'following_url': 'https://api.github.com/users/odzhychko/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/odzhychko/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/odzhychko/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/odzhychko/subscriptions',
#     'organizations_url': 'https://api.github.com/users/odzhychko/orgs',
#     'repos_url': 'https://api.github.com/users/odzhychko/repos',
#     'events_url': 'https://api.github.com/users/odzhychko/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/odzhychko/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'comments': 0,
#    'review_comments': 0,
#    'maintainer_can_modify': False,
#    'commits': 1,
#    'additions': 1,
#    'deletions': 1,
#    'changed_files': 1}},
#  'public': True,
#  'created_at': '2024-03-13T17:05:46Z',
#  'org': {'id': 66949436,
#   'login': 'modelix',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/orgs/modelix',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/66949436?'}}
